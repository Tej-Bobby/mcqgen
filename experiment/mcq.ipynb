# %%
import pandas pd
# Out:
# Running cells with 'env (Python 3.9.25)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\manch\env ipykernel --update-deps --force-reinstall'
